# %% [markdown]
# <a href="https://colab.research.google.com/github/mglsantana67-dotcom/PA-1f-grupo-b/blob/main/aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada
Lado1 = float (input("Digite o comprimento:"))
Lado2 = float (input("Digite a altura"))

#Processamento

area = Lado1 * Lado2

#saida

print  (f"O total da area e :{area} metros quadrados")
# Out:
# Digite o comprimento:2
# Digite a altura3
# O total da area e :6.0 metros quadrados

# %%
# Entrada
Numero = float (input("Digite o comprimento:"))

#Processamento

Dobro = Numero * 2

#saida

print  (f"O dobro da area e :{Dobro} ")
# Out:
# Digite o comprimento:50
# O dobro da area e :100.0

# %%
nota1 = float (input("Digite a nota:"))
nota2 = float (input("Digite a nota:"))
nota3 = float (input("Digite a nota:"))
nota4 = float (input("Digite a nota:"))

#Processamento

calculo_da_nota = (nota1 + nota2 + nota3 +nota4 ) / 4

#saida

print  (f"media e : {calculo_da_nota}")
# Out:
# Digite a nota:6
# Digite a nota:5
# Digite a nota:6
# Digite a nota:10
# media e : 6.75

# %%
# Entrada
nome = str (input("Digite o nome:"))
idade = int (input("Digite a idade:"))

#Processamento

#armazenar = nome = idade

#saida

print  (f"Ola nome :{nome} idade :{idade}")
# Out:
# Digite o nome:miguel
# Digite a idade:6
# Ola nome :miguel idade :6

# %%
# Operadores artiméticos

# pedir ao usuario para digitar 02 numero


#entrada

a = int (input("digite um numero"))
b = int (input("digite um numero"))


#processamento

# soma

soma = a + b
subtração = a - b

# subtração

subtracao = a - b
multiplicacao = a * b
divisao = a / b
div_int = a // b
resto = a % b
potencia = a ** b

#saida

print("")
print("-----------------operadores artiméticos----------------")
print("")
print("-------------------------soma------------------------")
print("")
print(f"o resultado da soma de {a} mais {b} é igual a :{soma}")
print("--------------------------------------------------------")
print("-------------------------subtração------------------------")
print("")
print(f"o resultado da diferença de {a} menos {b} é igual a :{subtração}")
print("")
print("--------------------------------------------------------")
print("-------------------------multiplicação------------------------")
print("")
print(f"o resultado da smultiplicação de {a} vezes {b} é igual a :{multiplicacao}")
print("--------------------------------------------------------")
print("-------------------------divisão------------------------")
print("")
print(f"o resultado da divisão de {a} dividido por {b} é igual a :{divisao}")
print("--------------------------------------------------------")
print("-------------------------divisão------------------------")
print("")
print(f"o resultado da divisão interira de {a} dividido por {b} é igual a :{div_int}")
print("--------------------------------------------------------")
print("-------------------------resto------------------------")
print("")
print(f"o resultado da divisão interira de {a} dividido por {b} o resto é igual a :{resto}")
print("--------------------------------------------------------")
print("")
print("-------------------------potencia------------------------")
print("")
print(f"o resultado da potenciação de {a} elevado {b} o resto é igual a :{potencia}")
print("--------------------------------------------------------")
print("")
# Out:
# digite um numero1500
# digite um numero658
#
# -----------------operadores artiméticos----------------
#
# -------------------------soma------------------------
#
# o resultado da soma de 1500 mais 658 é igual a :2158
# --------------------------------------------------------
# -------------------------subtração------------------------
#
# o resultado da diferença de 1500 menos 658 é igual a :842
#
# --------------------------------------------------------
# -------------------------multiplicação------------------------
#
# o resultado da smultiplicação de 1500 vezes 658 é igual a :987000
# --------------------------------------------------------
# -------------------------divisão------------------------
#
# o resultado da divisão de 1500 dividido por 658 é igual a :2.2796352583586628
# --------------------------------------------------------
# -------------------------divisão------------------------
#
# o resultado da divisão interira de 1500 dividido por 658 é igual a :2
# ...
