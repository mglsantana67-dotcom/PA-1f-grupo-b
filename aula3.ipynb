# %% [markdown]
# <a href="https://colab.research.google.com/github/mglsantana67-dotcom/PA-1f-grupo-b/blob/main/aula3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lado1 = 1
lado2 = 5

# calculo da area

area = lado1 * lado2

# calculo da area de um quadrado

areaquadrado = lado1 *lado1

# %%
__builtins__.print(areaquadrado)
# Out:
# 1

# %%
nome = "Miguel"
idade = 15
altura = 3

# %%
print (nome)

# %%
nome = "gustavo"

# %%
nome = "julia"

# %%
__builtins__.print(f":nome : {nome}, Idade : {idade}, Altura:  {altura}")
# Out:
# :nome : Miguel, Idade : 15, Altura:  3
